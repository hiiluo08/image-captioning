# %% [markdown]
# # 📈 Model Evaluation
#
# Evaluate the trained model and visualize results.

# %% [markdown]
# ## 1. Setup
#
# - Import libraries
# - Load config, vocabulary, and best checkpoint
# - Prepare test DataLoader

# %%
# TODO: Setup

# %% [markdown]
# ## 2. Quantitative Evaluation
#
# - Run evaluation on the test set
# - Compute BLEU-1, BLEU-2, BLEU-3, BLEU-4
# - (Optional) Compute METEOR, CIDEr

# %%
# TODO: Compute metrics

# %% [markdown]
# ## 3. Qualitative Evaluation
#
# - Show images with predicted vs. ground truth captions
# - Show good predictions and failure cases
# - (With attention) Visualize attention weights on images

# %%
# TODO: Visualize predictions

# %% [markdown]
# ## 4. Error Analysis
#
# - Analyze common failure patterns
# - Which types of images/captions are hardest?
# - Compare greedy vs. beam search results

# %%
# TODO: Error analysis

# %% [markdown]
# ## 5. Test on Custom Images
#
# - Upload your own images
# - Generate captions
# - Assess real-world performance

# %%
# TODO: Test on custom images
