# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# Analyze the Flickr8k/Flickr30k dataset to understand its characteristics.

# %% [markdown]
# ## 1. Setup & Import Libraries
#
# Import necessary libraries: `pandas`, `matplotlib`, `seaborn`, `PIL`, `collections.Counter`.

# %%
# TODO: Import libraries

# %% [markdown]
# ## 2. Load Dataset
#
# - Load the captions file (CSV/TXT)
# - Display basic info: number of images, number of captions, captions per image

# %%
# TODO: Load and explore the captions file

# %% [markdown]
# ## 3. Sample Images & Captions
#
# Display a grid of sample images with their captions to get a feel for the data.

# %%
# TODO: Show sample images with captions

# %% [markdown]
# ## 4. Caption Length Analysis
#
# - Distribution of caption lengths (histogram)
# - Mean, median, min, max caption length
# - Help decide max_caption_length for training

# %%
# TODO: Analyze caption lengths

# %% [markdown]
# ## 5. Word Frequency Analysis
#
# - Most common words (bar chart of top 30)
# - Vocabulary size at different frequency thresholds
# - WordCloud visualization (optional)

# %%
# TODO: Analyze word frequencies

# %% [markdown]
# ## 6. Image Analysis
#
# - Distribution of image sizes
# - Check for any corrupted images
# - Verify all referenced images exist on disk

# %%
# TODO: Analyze images

# %% [markdown]
# ## 7. Build Vocabulary
#
# - Test your Vocabulary class
# - Check vocab size with different freq_threshold values
# - Verify numericalize/denumericalize round-trip

# %%
# TODO: Build and test vocabulary

# %% [markdown]
# ## 8. Test Dataset & DataLoader
#
# - Create a CaptionDataset instance
# - Create a DataLoader with your custom collate_fn
# - Iterate one batch and verify shapes:
#   - images: [batch_size, 3, 224, 224]
#   - captions: [batch_size, max_seq_len]
#   - lengths: [batch_size]

# %%
# TODO: Test Dataset and DataLoader
